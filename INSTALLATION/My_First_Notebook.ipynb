# %% [markdown]
# # First Tutorial
# ## This is an installation demo.
#
# - Python is Versatile
# - Python is easy to learn

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
a = 10
b = 2
sum = a+b

# %%
print(f"Sum = {sum}")
# Out:
# Sum = 12
