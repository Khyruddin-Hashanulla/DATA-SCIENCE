# %%
import json

# %%
# Load the data
def load_data(filename):
  with open(filename, "r") as f:
      data = json.load(f)
  return data

# %%
data = load_data("StoreData.json")
print(data)
print(type(data))
# Out:
# [{'name': 'Sarah Jenkins', 'age': 36, 'rating': '5 ', 'feedback': 'Absolutely loved the experience! The interface is very intuitive.'}, {'name': 'David Chen', 'age': 42, 'rating': 'Three', 'feedback': 'It was okay, but the loading times were a bit slow on mobile.'}, {'name': 'Elena Rodriguez', 'rating': '4', 'feedback': 'Great service overall. Would appreciate more customization options.'}, {'name': 'Sarah Jenkins', 'age': 19, 'rating': '5', 'feedback': 'Perfect for what I needed. Highly recommend!'}, {'name': 'Aisha Patel', 'age': 51, 'rating': 'Five', 'feedback': "I found the navigation confusing and couldn't easily find my account settings."}]
# <class 'list'>

# %%
# Clean and Structure the data
def clean_data(data):
    text_to_num = {"one": 1, "two": 2, "three": 3, "four": 4, "five": 5}
    cleaned_data = []
    unique_users=set()
    
    for user in data:
        # Clean Ratings - Data consistency
        raw_rating = user["rating"].strip().lower()
        if(raw_rating in text_to_num):
            raw_rating=text_to_num[raw_rating]
        user["rating"]=raw_rating

        # Handle Missing Value
        raw_age=user.get("age")
        if(raw_age==None):
            user["age"]=None

        # Deduplication
        if(user["name"].strip() in unique_users):
            continue

        unique_users.add(user["name"])
        cleaned_data.append(user)

    return cleaned_data

# %%
clean_data(data)
# Out:
# [{'name': 'Sarah Jenkins',
#   'age': 36,
#   'rating': '5',
#   'feedback': 'Absolutely loved the experience! The interface is very intuitive.'},
#  {'name': 'David Chen',
#   'age': 42,
#   'rating': 3,
#   'feedback': 'It was okay, but the loading times were a bit slow on mobile.'},
#  {'name': 'Elena Rodriguez',
#   'rating': '4',
#   'feedback': 'Great service overall. Would appreciate more customization options.',
#   'age': None},
#  {'name': 'Aisha Patel',
#   'age': 51,
#   'rating': 5,
#   'feedback': "I found the navigation confusing and couldn't easily find my account settings."}]
